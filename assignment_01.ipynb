# %%
class Product:
    def __init__(self, name, price, stock):
        self.name = name
        self.price = price
        self.stock = stock

    def update_stock(self, quantity):
        self.stock += quantity

    def __str__(self):
        return f"Product: {self.name}, Price: ${self.price:.2f}, Stock: {self.stock}"


def main():
    products = {}

    while True:
        print("\nStore Product Manager")
        print("1. Add a new product")
        print("2. Update stock")
        print("3. View product details")
        print("4. Exit")
        choice = input("Enter your choice: ")

        if choice == "1":
            name = input("Enter product name: ")
            price = float(input("Enter product price: "))
            stock = int(input("Enter initial stock quantity: "))
            products[name] = Product(name, price, stock)
            print("Product added successfully!")

        elif choice == "2":
            name = input("Enter product name to update stock: ")
            if name in products:
                quantity = int(input("Enter quantity to add/remove (negative to remove): "))
                products[name].update_stock(quantity)
                print("Stock updated successfully!")
            else:
                print("Product not found!")

        elif choice == "3":
            name = input("Enter product name to view details: ")
            if name in products:
                print(products[name])
            else:
                print("Product not found!")

        elif choice == "4":
            print("Exiting program...")
            break
        else:
            print("Invalid choice! Please try again.")


if __name__ == "__main__":
    main()
# Out:
# Store Product Manager
# 1. Add a new product
# 2. Update stock
# 3. View product details
# 4. Exit
# Enter your choice: 1
# Enter product name: Pen
# Enter product price: 10
# Enter initial stock quantity: 10000
# Product added successfully!
#
# Store Product Manager
# 1. Add a new product
# 2. Update stock
# 3. View product details
# 4. Exit
# Enter your choice: 1
# Enter product name: Pencil
# Enter product price: 5
# Enter initial stock quantity: 5000
# Product added successfully!
#
# Store Product Manager
# 1. Add a new product
# 2. Update stock
# 3. View product details
# 4. Exit
# Enter your choice: 3
# Enter product name to view details: Pen
# Product: Pen, Price: $10.00, Stock: 10000
#
# Store Product Manager
# 1. Add a new product
# 2. Update stock
# 3. View product details
# 4. Exit
# Enter your choice: 2
# Enter product name to update stock: Pen
# Enter quantity to add/remove (negative to remove): 200
# Stock updated successfully!
#
# Store Product Manager
# 1. Add a new product
# 2. Update stock
# 3. View product details
# 4. Exit
# Enter your choice: 3
# Enter product name to view details: Pen
# Product: Pen, Price: $10.00, Stock: 10200
#
# Store Product Manager
# 1. Add a new product
# 2. Update stock
# 3. View product details
# 4. Exit
# Enter your choice: 4
# Exiting program...
